# %%
import requests
from bs4 import BeautifulSoup

url = "https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing%20and%20utm_campaign=eruwebsite_swmp"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

course_name = soup.find("h1", class_="header__title")
if course_name:
    course_name = course_name.get_text().strip()

print(f"Course Name: {course_name}")
# Out:
# Course Name: Strategic Wealth Manager Program

# %%
#online1.gsb.columbia.edu
import requests
from bs4 import BeautifulSoup

def extract_course_name(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    course_name = soup.find("h1", class_="header__title")
    if course_name:
        return course_name.get_text().strip()
    return "Course name not found"

# List of URLs
urls = [
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing&utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing and utm_campaign=eruwebsite_gbp",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing and utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing&utm_campaign=eruwebsite_gbp",

]

for url in urls:
    course_name = extract_course_name(url)
    print(f"Course Name for {url}: {course_name}")
# Out:
# Course Name for https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp: Strategic Wealth Manager Program
# Course Name for https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp: Strategic Wealth Manager Program
# Course Name for https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo: Chief Marketing Officer Program
# Course Name for https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo: Chief Financial Officer Program
# Course Name for https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo: Chief Financial Officer Program
# ...

# %%
#online1.gsb.columbia.edu
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_course_name(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    course_name = soup.find("h1", class_="header__title")
    if course_name:
        return course_name.get_text().strip()
    return "Course name not found"

# List of URLs
urls = [
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing&utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing and utm_campaign=eruwebsite_gbp",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing and utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing&utm_campaign=eruwebsite_gbp",

]

course_names = []

for url in urls:
    course_name = extract_course_name(url)
    course_names.append(course_name)

# Create a DataFrame
data = {"Course Name": course_names}
df = pd.DataFrame(data)

# Save to Excel
df.to_excel("Erudituscourse_names.xlsx", index=False)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing%20and%20utm_campaign=eruwebsite_swmp"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

duration_element = soup.find("h3", text="DURATION")
if duration_element:
    course_duration = duration_element.find_next("p").get_text(separator="\n", strip=True)
    print("Course Duration:", course_duration)
else:
    print("Course Duration not found.")
# Out:
# Course Duration: 9 to 12 Months
# Online and In Person

# %%
import requests
from bs4 import BeautifulSoup

urls = [
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing&utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing and utm_campaign=eruwebsite_gbp",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing and utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing&utm_campaign=eruwebsite_gbp",

]

for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    duration_element = soup.find("h3", text="DURATION")
    if duration_element:
        course_duration = duration_element.find_next("p").get_text(separator="\n", strip=True)
        print(f"Course Duration for {url}: {course_duration}")
    else:
        print(f"Course Duration not found for {url}.")
# Out:
# Course Duration for https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp: 9 to 12 Months
# Online and In Person
# Course Duration for https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp: 9 to 12 Months
# Online and In Person
# Course Duration for https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo: 9 to 12 Months
# Online and In Person
# Course Duration for https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo: 9 to 12 Months
# Online and In Person
# Course Duration for https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo: 9 to 12 Months
# Online and In Person
# ...

# %%
#https://online1.gsb.columbia.edu
import requests
from bs4 import BeautifulSoup
import pandas as pd

urls = [
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing&utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing and utm_campaign=eruwebsite_gbp",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing and utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing&utm_campaign=eruwebsite_gbp",

]

data = []

for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    duration_element = soup.find("h3", text="DURATION")
    if duration_element:
        course_duration = duration_element.find_next("p").get_text(separator="\n", strip=True)
        data.append({"URL": url, "Course Duration": course_duration})
    else:
        data.append({"URL": url, "Course Duration": "Not found"})

# Creating a DataFrame
df = pd.DataFrame(data)

# Exporting to Excel
df.to_excel("Erudituscourse_data.xlsx", index=False)

# %%
from bs4 import BeautifulSoup
import requests

url = "https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing%20and%20utm_campaign=eruwebsite_swmp"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

fee_element = soup.find("h3", text="PROGRAM FEE")
if fee_element:
    course_fee = fee_element.find_next("span", class_="js-number-localized").get_text()
    print("Course Fee:", course_fee)
else:
    print("Course Fee not found")
# Out:
# Course Fee: US$20,000

# %%
from bs4 import BeautifulSoup
import requests

urls = [
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing&utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing and utm_campaign=eruwebsite_gbp",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing and utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing&utm_campaign=eruwebsite_gbp",

]

for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    fee_element = soup.find("h3", text="PROGRAM FEE")
    if fee_element:
        course_fee = fee_element.find_next("span", class_="js-number-localized").get_text()
        print(f"Course Fee for {url}: {course_fee}")
    else:
        print(f"Course Fee not found for {url}")
# Out:
# Course Fee for https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp: US$20,000
# Course Fee for https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp: US$20,000
# Course Fee for https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo: US$28,000
# Course Fee for https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo: US$28,000
# Course Fee for https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo: US$28,000
# Course Fee for https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo: US$28,000
# ...

# %%
#https://online1.gsb.columbia.edu
from bs4 import BeautifulSoup
import requests
import pandas as pd

urls = [
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing&utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing and utm_campaign=eruwebsite_gbp",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing and utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing&utm_campaign=eruwebsite_gbp",

]

data = []

for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    fee_element = soup.find("h3", text="PROGRAM FEE")
    if fee_element:
        course_fee = fee_element.find_next("span", class_="js-number-localized").get_text()
        data.append({"URL": url, "Course Fee": course_fee})
    else:
        data.append({"URL": url, "Course Fee": "Not Found"})

# Create a DataFrame
df = pd.DataFrame(data)

# Export data to Excel
file_name = "Erudituscourse_fees.xlsx"
df.to_excel(file_name, index=False, engine='openpyxl')

print(f"Data exported to {file_name}")
# Out:
# Data exported to Erudituscourse_fees.xlsx

# %%
from bs4 import BeautifulSoup
import requests

url = "https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing%20and%20utm_campaign=eruwebsite_swmp"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# Find the section related to Core Modules
core_modules_section = soup.find("li", class_="curriculum__row")

if core_modules_section:
    # Extract the curriculum panel
    curriculum_panel = core_modules_section.find("div", class_="curriculum__panel")

    if curriculum_panel:
        # Find all the text under core modules
        core_modules_text = curriculum_panel.get_text(separator="\n")
        print(core_modules_text)
# Out:
# The Strategic Wealth Manager Program features three core modules that will equip you with the tools and frameworks to understand your clients’ investment needs and develop value propositions customized to their risk profiles and investment goals. You will explore the impact of various asset classes, investment strategies, risk management, and asset allocation and gain hands-on experience in managing portfolios to suit client needs. The program will also sharpen your client management skills and provide you with strategies to expand your client base.
#
#
#
#
#
#
# Investment Strategies
#
#
#
#
# Introduction to Markets, Shorting, and Leverage
#
#
# Major Asset Classes and Historical Performance
#
#
# Measuring and Evaluating Investment Risk
#
#
# Fixed Income I: Bonds and the Yield Curve
#
#
# Understanding and Monitoring Corporate Leverage
#
#
# Drivers of Interest Rates and the Fed
#
#
# Stocks: Valuation and Investment Strategies
#
#
# Option Basics
#
#
# ...

# %%
#https://online1.gsb.columbia.edu
from bs4 import BeautifulSoup
import requests
import pandas as pd

urls = [
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing and utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/strategic-wealth-manager-program?utm_source=content_marketing&utm_campaign=eruwebsite_swmp",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing and utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-financial-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cfo",
"https://online1.gsb.columbia.edu/chief-marketing-officer?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_cmo",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing and utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/venture-capital-private-equity?utm_source=content_marketing&utm_campaign=eruwebsite_cbs_vcpe",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing&utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing and utm_campaign=eruwebsite_gbp",
"https://online1.gsb.columbia.edu/executive-program-in-management?utm_source=content_marketing and utm_campaign=direct_eruwebsite_epm",
"https://online1.gsb.columbia.edu/global-banking-program?utm_source=content_marketing&utm_campaign=eruwebsite_gbp",
]

all_core_modules = []

for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the section related to Core Modules
    core_modules_section = soup.find("li", class_="curriculum__row")

    if core_modules_section:
        # Extract the curriculum panel
        curriculum_panel = core_modules_section.find("div", class_="curriculum__panel")

        if curriculum_panel:
            # Find all the text under core modules
            core_modules_text = curriculum_panel.get_text(separator="\n")
            all_core_modules.append(core_modules_text)

# Save to Excel
df = pd.DataFrame({"Core Modules": all_core_modules})
df.to_excel("Erudituscore_modules_data.xlsx", index=False)
